# %%
def solution(places):
    answer = []
    
    for place in places:
        ans = 1
        
        p = []
        i = 0
        for a in place:
            j = 0
            
            for b in a:
                if (b == 'P'):
                    p.append(str(i) + " "  + str(j))
                j += 1
            i += 1
        
        
        print(p)
        i = 0
        for a in p:
            for b in p[i + 1:]:
                if abs(int(a.split(' ')[0]) - int(b.split(' ')[0])) + abs(int(a.split(' ')[1]) - int(b.split(' ')[1])) <= 2:
                    if (int(a.split(' ')[0]) - int(b.split(' ')[0]) == 0 and abs(int(a.split(' ')[1]) - int(b.split(' ')[1])) == 2):
                        if (place[int(a.split(' ')[0])][(int(a.split(' ')[1]) + int(b.split(' ')[1])) / 2] == 'X'):
                            continue
                    elif (int(a.split(' ')[1]) - int(b.split(' ')[1]) == 0 and abs(int(a.split(' ')[0]) - int(b.split(' ')[0])) == 2):
                        if (place[(int(a.split(' ')[0]) + int(b.split(' ')[0])) / 2][int(a.split(' ')[1])] == 'X'):
                            continue
                    elif (abs(int(a.split(' ')[0]) - int(b.split(' ')[0])) == 1 and abs(int(a.split(' ')[1]) - int(b.split(' ')[1])) == 1):
                        if (place[int(a.split(' ')[0]) + 1][int(a.split(' ')[1])] == 'X' and place[int(a.split(' ')[0])][int(a.split(' ')[1]) + 1] == 'X'):
                            continue
                    else:
                        ans = 0
                        
            i += 1
        
        answer.append(ans)
        
    
    return answer

# %%
a = "0 0"
b = "0 2"

# %%
place = 	[["POOOP", "OXXOX", "OPXPX", "OOXOX", "POXXP"], ["POOPX", "OXPXP", "PXXXO", "OXXXO", "OOOPP"], ["PXOPX", "OXOXP", "OXPXX", "OXXXP", "POOXX"], ["OOOXX", "XOOOX", "OOOXX", "OXOOX", "OOOOO"], ["PXPXP", "XPXPX", "PXPXP", "XPXPX", "PXPXP"]]

# %%
place[int(a.split(' ')[0])][(int(a.split(' ')[1]) + int(b.split(' ')[1])) / 2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-7be4a78892a5> in <module>
# ----> 1 place[int(a.split(' ')[0])][(int(a.split(' ')[1]) + int(b.split(' ')[1])) / 2]
#
# TypeError: list indices must be integers or slices, not float

# %%
int(a.split(' ')[0])
# Out:
# 0

# %%
(int(a.split(' ')[1]) + int(b.split(' ')[1])) / 2
# Out:
# 1.0

# %%
if (place[int(a.split(' ')[0])][int(a.split(' ')[0])] == 'X' and place[int(a.split(' ')[0])][int(a.split(' ')[0])] == 'X'):
    print("True")

# %%
def solution(n, k, cmd):
    answer = ''
    ans = []
    
    for i in range(n):
        ans.append('O')
        
    d = 0
    di = []
    for c in cmd:
        print(c)
        print(k)
        print(ans)
        if c[0] == 'U':
            i = int(c[2])
            
            while(i > 0):
                k -= 1
                
                if (k < 0):
                    k += n
                
                if (ans[k] == 'O'):
                    i -= 1
        elif c[0] == 'D':
            i = int(c[2])
            
            while(i > 0):
                k += 1
                
                if (k >= n):
                    k -= n
                
                if (ans[k] == 'O'):
                    i -= 1
                    
        elif c[0] == 'C':
            ans[k] = 'X'
            di.append(k)
            d += 1
            
            a = -1
            
            for i in range(k + 1, n):
                if (ans[i] == 'O'):
                    a = 0;
                    
            if (a == -1):
                i = 1
                while(i > 0):
                    k -= 1
                
                    if (k < 0):
                        k += n
                
                    if (ans[k] == 'O'):
                        i -= 1
            else:
                i = 1
                while(i > 0):
                    k += 1
                
                    if (k >= n):
                        k -= n
                
                    if (ans[k] == 'O'):
                        i -= 1
        else:
            d -= 1
            ans[di.pop(0)] = 'O'
    
    
    for i in range(n):
        answer += ans[i]
    return answer

# %%
print(solution(	8, 2, ["D 2", "C", "U 3", "C", "D 4", "C", "U 2", "Z", "Z"]))
# Out:
# D 2
# 2
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# C
# 4
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# U 3
# 5
# ['O', 'O', 'O', 'O', 'X', 'O', 'O', 'O']
# C
# 1
# ['O', 'O', 'O', 'O', 'X', 'O', 'O', 'O']
# D 4
# 2
# ['O', 'X', 'O', 'O', 'X', 'O', 'O', 'O']
# C
# 7
# ['O', 'X', 'O', 'O', 'X', 'O', 'O', 'O']
# U 2
# 6
# ['O', 'X', 'O', 'O', 'X', 'O', 'O', 'X']
# Z
# 3
# ['O', 'X', 'O', 'O', 'X', 'O', 'O', 'X']
# Z
# 3
# ['O', 'X', 'O', 'O', 'O', 'O', 'O', 'X']
# OOOOOOOX

# %%
for i in range(6, 8):
    print(i)
# Out:
# 6
# 7

# %%
solution(	8, 2, ["D 2", "C", "U 3", "C", "D 4", "C", "U 2", "Z", "Z"])
# Out:
# D 2
# 2
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# C
# 4
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# U 3
# 5
# ['O', 'O', 'O', 'O', 'X', 'O', 'O', 'O']
# C
# 1
# ['O', 'O', 'O', 'O', 'X', 'O', 'O', 'O']
# D 4
# 2
# ['O', 'X', 'O', 'O', 'X', 'O', 'O', 'O']
# C
# 7
# ['O', 'X', 'O', 'O', 'X', 'O', 'O', 'O']

# %%
def solution(n, k, cmd):
    answer = ''
    l = []
    
    for i in range(n):
        l.append(i)
        
    di = []
    for c in cmd:
        if c[0] == 'U':
            k -= int(c[2])
            
            if (k < 0):
                k += len(l)
        elif c[0] == 'D':
            k += int(c[2])
            
            if (k >= len(l)):
                k -= len(l)
                    
        elif c[0] == 'C':
            di.append(l[k])
            
            del l[k]
            if (k == len(l)):
                k -= 1
                
                if (k < 0):
                    k += len(l)
            
        else:
            ki = l[k]
            l.append(di[-1])
            del di[-1]
            
            l.sort()
            k = l.index(ki)
            
        print(c)
        print(k, l)
        print(di)
        
    
    for i in range(n):
        if (i in l):
            answer += 'O'
        else:
            answer += 'X'
    return answer

# %%
print(solution(	8, 2, ["D 2", "C", "U 3", "C", "D 4", "C", "U 2", "Z", "Z", "U 1", "C", "U 3", "C", "D 2", "C", "Z"]))
# Out:
# D 2
# 4 [0, 1, 2, 3, 4, 5, 6, 7]
# []
# C
# 4 [0, 1, 2, 3, 5, 6, 7]
# [4]
# U 3
# 1 [0, 1, 2, 3, 5, 6, 7]
# [4]
# C
# 1 [0, 2, 3, 5, 6, 7]
# [4, 1]
# D 4
# 5 [0, 2, 3, 5, 6, 7]
# [4, 1]
# C
# 4 [0, 2, 3, 5, 6]
# [4, 1, 7]
# U 2
# 2 [0, 2, 3, 5, 6]
# [4, 1, 7]
# Z
# 2 [0, 2, 3, 5, 6, 7]
# [4, 1]
# Z
# 3 [0, 1, 2, 3, 5, 6, 7]
# [4]
# U 1
# 2 [0, 1, 2, 3, 5, 6, 7]
# [4]
# C
# 2 [0, 1, 3, 5, 6, 7]
# [4, 2]
# U 3
# 5 [0, 1, 3, 5, 6, 7]
# [4, 2]
# C
# 4 [0, 1, 3, 5, 6]
# [4, 2, 7]
# D 2
# 1 [0, 1, 3, 5, 6]
# [4, 2, 7]
# C
# 1 [0, 3, 5, 6]
# [4, 2, 7, 1]
# Z
# 2 [0, 1, 3, 5, 6]
# [4, 2, 7]
# OOXOXOOX

# %% [markdown]
# # OXXOXOOO

# %%
l = [0, 2, 3, 5, 6]
ki = 3
print(l.index(ki))
# Out:
# 2

# %%
def cal(place, p):
    i = 0
    for a in p:
        for b in p[i + 1:]:
            print(a, b)
    i+=1
    print("\n")
    
    return 1

def solution(places):
    answer = []
    
    for place in places:
        p = []
        i = 0
        for a in place:
            j = 0
            
            for b in a:
                if (b == 'P'):
                    p.append(str(i) + " "  + str(j))
                j += 1
            i += 1
        
        print(p)
        answer.append(cal(place, p))
        
    
    return answer

# %%
solution(	[["POOOP", "OXXOX", "OPXPX", "OOXOX", "POXXP"], ["POOPX", "OXPXP", "PXXXO", "OXXXO", "OOOPP"], ["PXOPX", "OXOXP", "OXPXX", "OXXXP", "POOXX"], ["OOOXX", "XOOOX", "OOOXX", "OXOOX", "OOOOO"], ["PXPXP", "XPXPX", "PXPXP", "XPXPX", "PXPXP"]])
# Out:
# ['0 0', '0 4', '2 1', '2 3', '4 0', '4 4']
# 0 0 0 4
# 0 0 2 1
# 0 0 2 3
# 0 0 4 0
# 0 0 4 4
# 0 4 0 4
# 0 4 2 1
# 0 4 2 3
# 0 4 4 0
# 0 4 4 4
# 2 1 0 4
# 2 1 2 1
# 2 1 2 3
# 2 1 4 0
# 2 1 4 4
# 2 3 0 4
# 2 3 2 1
# 2 3 2 3
# 2 3 4 0
# 2 3 4 4
# 4 0 0 4
# 4 0 2 1
# 4 0 2 3
# 4 0 4 0
# 4 0 4 4
# 4 4 0 4
# 4 4 2 1
# 4 4 2 3
# 4 4 4 0
# 4 4 4 4
#
#
# ['0 0', '0 3', '1 2', '1 4', '2 0', '4 3', '4 4']
# 0 0 0 3
# 0 0 1 2
# 0 0 1 4
# 0 0 2 0
# 0 0 4 3
# 0 0 4 4
# 0 3 0 3
# 0 3 1 2
# 0 3 1 4
# 0 3 2 0
# 0 3 4 3
# 0 3 4 4
# 1 2 0 3
# 1 2 1 2
# 1 2 1 4
# 1 2 2 0
# 1 2 4 3
# 1 2 4 4
# 1 4 0 3
# 1 4 1 2
# 1 4 1 4
# 1 4 2 0
# 1 4 4 3
# 1 4 4 4
# 2 0 0 3
# 2 0 1 2
# 2 0 1 4
# 2 0 2 0
# 2 0 4 3
# 2 0 4 4
# 4 3 0 3
# 4 3 1 2
# 4 3 1 4
# 4 3 2 0
# 4 3 4 3
# 4 3 4 4
# 4 4 0 3
# 4 4 1 2
# 4 4 1 4
# 4 4 2 0
# 4 4 4 3
# 4 4 4 4
#
#
# ['0 0', '0 3', '1 4', '2 2', '3 4', '4 0']
# 0 0 0 3
# 0 0 1 4
# 0 0 2 2
# 0 0 3 4
# 0 0 4 0
# 0 3 0 3
# 0 3 1 4
# 0 3 2 2
# 0 3 3 4
# 0 3 4 0
# 1 4 0 3
# 1 4 1 4
# 1 4 2 2
# ...
